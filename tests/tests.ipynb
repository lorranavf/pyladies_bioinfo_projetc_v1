# %%
import sys

sys.path.append('../code')

# %%
from alphabet import Alphabet, DNAAlphabet, RNAAlphabet, ProteinAlphabet, CustomAlphabet

# %%
dna_alphabet = DNAAlphabet()
print("Alphabet Symbols:", dna_alphabet.symbols)
print("Alphabet Dictionary:", dna_alphabet.dictionary)
print("Alphabet Name:", dna_alphabet.name)
# Out:
# Alphabet Symbols: ['A', 'C', 'G', 'T']
# Alphabet Dictionary: {'A': 'Adenine', 'C': 'Cytosine', 'G': 'Guanine', 'T': 'Thymine'}
# Alphabet Name: dna

# %%
from sequence import BaseSeq, DNASeq, RNASeq, ProteinSeq, CustomSeq, Seq, SeqObj

# %%
all(base in DNAAlphabet().symbols for base in "ATCG")
# Out:
# True

# %%
[base in RNAAlphabet().symbols for base in "AUCG"]
# Out:
# [True, True, True, True]

# %%
sequence = Seq("ATCGTCACGTGGCGTAAATATCGTC")

# %%
sequence.sequence
# Out:
# 'ATCGTCACGTGGCGTAAATATCGTC'

# %%
print(sequence)
# Out:
# ATCGTCACGTGGCGTAAATATCGTC

# %%
sequence.gc_content()

# %%
sequence.length()
# Out:
# 25

# %%
seqobj = SeqObj(sequence, 'IRC', 'corn')

# %%
seqobj
# Out:
# SeqObj(id='IRC', description='corn', seq=DNASeq('ATCGTCACGTGGCGTAAATATCGTC'))
